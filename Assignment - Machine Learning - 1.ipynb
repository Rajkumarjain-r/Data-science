# %% [markdown]
# ![Screenshot%202023-08-01%20142250.jpg](attachment:Screenshot%202023-08-01%20142250.jpg)

# %% [markdown]
# Q1:
#
# AI is the super set of all the of the data science universe
# ML is a subset of AI. Machine learning where we use ML algorithms for classification regression super vised unsupervised semi super vised and reinforcement learning for prediction classification and clustering
#
# DL learnig is a subset of ML where we used human like neural neywork algos for prediction classification eg tensorflow

# %% [markdown]
# Q2
#
# Supervised learing has two types:
#
#     Classification: here the output is a categorical feature eg grade of a student like A, B , B+
#     Regression: Here the output is a continous feature eg prediction of India scoring runs based on that ground india has played, or product pricing

# %% [markdown]
# Q3
#
# Unsupervised learning is where there is no specific output but we convert the data in different clusters or groups. here the dara is unlabbelled
#
# eg: given data of cars based on the size of the cars groups into sedan suv using ML algo

# %% [markdown]
# Q4
# ML: Machine Learning
#
# Machine Learning is a subset of Artificial Intelligence (AI) that focuses on the development of algorithms and statistical models that enable computers to learn from data without being explicitly programmed. The goal of machine learning is to allow computers to improve their performance on a specific task through experience (data).
# AI: Artificial Intelligence
#
# Artificial Intelligence is a broader field that encompasses the development of intelligent machines that can perform tasks that typically require human intelligence. AI includes various techniques like machine learning, natural language processing, computer vision, robotics, and more.
# DL: Deep Learning
#
# Deep Learning is a specialized subset of machine learning that involves training artificial neural networks with multiple layers (deep neural networks) to learn hierarchical representations of data. Deep learning has shown remarkable success in tasks like image and speech recognition, natural language processing, and other complex pattern recognition tasks.
# DS: Data Science
#
# Data Science is an interdisciplinary field that involves the extraction of knowledge and insights from structured and unstructured data. It combines various techniques from statistics, mathematics, machine learning, data engineering, and domain expertise to analyze data, make predictions, and support decision-making processes.

# %% [markdown]
#  Q5
#
# supervised learning requires labeled data for training, unsupervised learning works with unlabeled data to find patterns, and semi-supervised learning uses both labeled and unlabeled data to improve the learning process. Each type of learning has its unique applications and use cases in machine learning and data analysis.

# %% [markdown]
# Q6
#
# Train data is data by which the model is trained
# Validation data is data by which hyper parameter tuning is doen for model accuracy
# test data is to test the model for find the model accuring. Test data is an unknown data to the model

# %% [markdown]
# Q7
#
# Unsupervised learning can be effectively used for anomaly detection tasks. Anomaly detection involves identifying rare and abnormal instances or patterns in a dataset that differ significantly from the majority of the data.

# %%
Q8

Common Supervised Learning Algorithms:

Linear Regression
Logistic Regression
Decision Trees
Random Forest
Support Vector Machines (SVM)
k-Nearest Neighbors (k-NN)
Naive Bayes
Gradient Boosting (e.g., XGBoost, LightGBM)
Neural Networks (Deep Learning)
Ridge Regression
Lasso Regression
Elastic Net Regression
Gaussian Processes
AdaBoost
Common Unsupervised Learning Algorithms:

K-means Clustering
DBSCAN (Density-Based Spatial Clustering of Applications with Noise)
Hierarchical Clustering
Gaussian Mixture Models (GMM)
Principal Component Analysis (PCA)
t-Distributed Stochastic Neighbor Embedding (t-SNE)
Autoencoders
Isolation Forest
Local Outlier Factor (LOF)
Self-Organizing Maps (SOM)
Mean Shift Clustering
Independent Component Analysis (ICA)
Non-negative Matrix Factorization (NMF)
Restricted Boltzmann Machines (RBMs)
